# %%
import matplotlib.pyplot as plt

# Data
labels = ['Clothes Washer', 'Shower', 'Toilet', 'Faucet', 'Leak', 'Other']
percentages = [17, 24, 20, 19, 12, 8]

# Create a pie chart
plt.pie(percentages, labels=labels, autopct="%1.1f%%", wedgeprops={'linewidth': 0})
plt.title("Water Usage Around the World")
plt.axis("equal")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randint(20, 100, 6)
total = sum(data)
data_per = data/total*100
plt.pie(data_per, labels = [round(i,2) for i in (list(data_per))], startangle=90, counterclock=False)
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %%
# Data
import matplotlib.pyplot as plt
labels = ['Apples', 'Bananas', 'Grapes', 'Oranges']
sizes = [25, 30, 15, 30]

# Plot
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"))

wedges, texts = ax.pie(sizes, wedgeprops=dict(width=0.5), startangle=-40)

# Inner circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Add labels
ax.legend(wedges, labels,
      title="Fruits",
      loc="center left",
      bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, size=12, weight="bold")

ax.set_title("Fruit Distribution")

plt.show()

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
size = 6
cars = ['AUDI', 'BMW', 'FORD', 
		'TESLA', 'JAGUAR', 'MERCEDES']

data = np.array([[23, 16], [17, 23],
				[35, 11], [29, 33],
				[12, 27], [41, 42]])

# normalizing data to 2 pi
norm = data / np.sum(data)*2 * np.pi

# obtaining ordinates of bar edges
left = np.cumsum(np.append(0, 
						norm.flatten()[:-1])).reshape(data.shape)
    
# Creating color scale
cmap = plt.get_cmap("tab20c")
outer_colors = cmap(np.arange(6)*4)
inner_colors = cmap(np.array([1, 2, 5, 6, 9,
							10, 12, 13, 15,
							17, 18, 20 ]))

# Creating plot
fig, ax = plt.subplots(figsize =(10, 7),
					subplot_kw = dict(polar = True))

ax.bar(x = left[:, 0],
	width = norm.sum(axis = 1),
	bottom = 1-size,
	height = size,
	color = outer_colors, 
	edgecolor ='w',
	linewidth = 1,
	align ="edge")

ax.bar(x = left.flatten(),
	width = norm.flatten(),
	bottom = 1-2 * size,
	height = size,
	color = inner_colors,
	edgecolor ='w',
	linewidth = 1,
	align ="edge")

ax.set(title ="Nested pie chart")
ax.set_axis_off()

# show plot
plt.show()
# Out:
# [[0.46768046 0.32534293]
#  [0.34567686 0.46768046]
#  [0.71168766 0.22367326]
#  [0.58968406 0.67101979]
#  [0.2440072  0.54901619]
#  [0.83369125 0.85402519]]
#
# [[0.         0.46768046]
#  [0.79302339 1.13870025]
#  [1.60638071 2.31806837]
#  [2.54174163 3.13142569]
#  [3.80244548 4.04645267]
#  [4.59546887 5.42916012]]
# ...

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

courses_df = pd.read_csv('../Data/processed_data.csv', sep=',',engine='python', encoding='utf-8')

field_df = pd.DataFrame({'general': courses_df['general'],
                    	 'specify': courses_df['specify'],
                         'count': 0}).groupby(by=['general', 'specify']).count().reset_index().sort_values(by=['general', 'count'], ascending=[True, False]).set_index(['general', 'specify'])

# normalizing data to 2 pi
norm = field_df / np.sum(field_df)*2 * np.pi
# print(norm)

# obtaining ordinates of bar edges
# Same as code: np.cumsum(np.append(0, norm['count'].list.flatten()[:-1])).reshape(field_df.shape)
left = list(np.cumsum(np.insert(norm['count'].values.reshape(-1), 0, 0))[:-1])

print(left)
# Out:
# [0.0, 0.18134083884635854, 0.29783858986280703, 0.374771066949141, 0.8594456725930447, 1.1517890855211137, 1.3891807291018012, 1.611185877265222, 1.8309929546547477, 1.9837588734404679, 2.411283638963095, 2.553059203879339, 2.6794482733783163, 2.801441201329503, 2.90475052770258, 3.3146907270340447, 3.5388939459713606, 3.593845715318742, 3.753205846426148, 3.8850900928598633, 4.004884950037154, 4.080718391736541, 4.135670161083922, 4.180730611948775, 4.209305532009413, 4.235682381296156, 4.246672735165633, 4.459885600233473, 4.585175634345502, 4.657711969884045, 4.722555057713955, 4.76212033164407, 4.885212294982204, 4.934668887394848, 5.01709654141592, 5.220418088001231, 5.374283042173898, 5.513860536316247, 5.643546711976067, 5.733667613705773, 5.764440604540306, 5.7809261353445205, 5.985346717316779, 6.160093343841452, 6.223837396284415]
# ...
